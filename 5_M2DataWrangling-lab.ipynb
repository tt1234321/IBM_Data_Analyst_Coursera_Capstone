# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here

# Selecting duplicate rows except first 
# occurrence based on all columns
duplicate = df[df.duplicated()]
  
print("Duplicate Rows :")
  
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
#       Respondent                                         MainBranch Hobbyist  \
# 1168        2339                     I am a developer by profession      Yes
# 1169        2342                     I am a developer by profession      Yes
# 1170        2343                     I am a developer by profession      Yes
# 1171        2344                     I am a developer by profession      Yes
# 1172        2347                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 2297        4674  I am not primarily a developer, but I write co...      Yes
# 2298        4675                     I am a developer by profession      Yes
# 2299        4676                     I am a developer by profession      Yes
# 2300        4677                     I am a developer by profession      Yes
# 2301        4679                     I am a developer by profession      Yes
#
# ...

# %%
#Duplicats in column respondent
duplicate_respondent=df.duplicated(subset=['Respondent'])

# %%
duplicate_respondent.value_counts()
# Out:
# False    11398
# True       154
# dtype: int64

# %%
df.duplicated(keep='first').sum()
# Out:
# 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
df1=df.drop_duplicates() #creats new dataframe df1 without duplicates

# %%
df1.duplicated(keep='first').sum()
# Out:
# 0

# %%
df1.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
df.info() #value is 11552 entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11552 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11552 non-null  int64
#  1   MainBranch              11552 non-null  object
#  2   Hobbyist                11552 non-null  object
#  3   OpenSourcer             11552 non-null  object
#  4   OpenSource              11471 non-null  object
#  5   Employment              11552 non-null  object
#  6   Country                 11552 non-null  object
#  7   Student                 11499 non-null  object
#  8   EdLevel                 11436 non-null  object
#  9   UndergradMajor          10812 non-null  object
#  10  EduOther                11388 non-null  object
#  11  OrgSize                 11454 non-null  object
#  12  DevType                 11485 non-null  object
#  13  YearsCode               11543 non-null  object
# ...

# %%
df1.info() #value is 11398 entries (check above) - from question above there were 154 duplicate rows i.e. 11552 = 11398 + 154
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11398 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11398 non-null  int64
#  1   MainBranch              11398 non-null  object
#  2   Hobbyist                11398 non-null  object
#  3   OpenSourcer             11398 non-null  object
#  4   OpenSource              11317 non-null  object
#  5   Employment              11398 non-null  object
#  6   Country                 11398 non-null  object
#  7   Student                 11347 non-null  object
#  8   EdLevel                 11286 non-null  object
#  9   UndergradMajor          10661 non-null  object
#  10  EduOther                11234 non-null  object
#  11  OrgSize                 11302 non-null  object
#  12  DevType                 11333 non-null  object
#  13  YearsCode               11389 non-null  object
# ...

# %%
# or compare sum of duplicates in original dataframe and df1 (after duplicates drop)
sum_dupl1=df1.duplicated(keep='first').sum()
sum_dupl=df.duplicated(keep='first').sum()
print("Sum of duplicates before drop:", sum_dupl, "versus some of duplicates after drop:", sum_dupl1)
# Out:
# Sum of duplicates before drop: 154 versus some of duplicates after drop: 0

# %% [markdown]
# ## Finding Missing values

# %%
#MY WORK WITH SELECTING ROWS AND COLUMS FOR REVIEW

# %%
df.iloc[[0,3,9,15], [0,5,6]] # selecting df for review
# Out:
#     Respondent          Employment         Country
# 0            4  Employed full-time   United States
# 3           16  Employed full-time  United Kingdom
# 9           24  Employed full-time          Israel
# 15          39  Employed full-time   United States

# %%
df.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame
# Out:
#            Employment         Country Student
# 0  Employed full-time   United States      No
# 1  Employed full-time     New Zealand      No
# 2  Employed full-time   United States      No
# 3  Employed full-time  United Kingdom      No
# 4  Employed full-time       Australia      No

# %%
df.iloc[1:12, 15:30]
# Out:
#    YearsCodePro           CareerSat                              JobSat  \
# 1             4  Slightly satisfied                  Slightly satisfied
# 2             8      Very satisfied                      Very satisfied
# 3             3      Very satisfied                  Slightly satisfied
# 4             2  Slightly satisfied  Neither satisfied nor dissatisfied
# 5            13   Very dissatisfied                      Very satisfied
# 6             4      Very satisfied               Slightly dissatisfied
# 7            18  Slightly satisfied                   Very dissatisfied
# 8             1  Slightly satisfied                  Slightly satisfied
# 9             1      Very satisfied                      Very satisfied
# 10            1      Very satisfied                      Very satisfied
# 11            8      Very satisfied                      Very satisfied
#
#               MgrIdiot MgrMoney                 MgrWant  \
# ...

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    Respondent  MainBranch  Hobbyist  OpenSourcer  OpenSource  Employment  \
# 0       False       False     False        False       False       False
# 1       False       False     False        False       False       False
# 2       False       False     False        False       False       False
# 3       False       False     False        False       False       False
# 4       False       False     False        False       False       False
#
#    Country  Student  EdLevel  UndergradMajor  ...  WelcomeChange  \
# 0    False    False    False           False  ...          False
# 1    False    False    False           False  ...          False
# 2    False    False    False           False  ...          False
# 3    False    False    False            True  ...          False
# 4    False    False    False           False  ...          False
#
#    SONewContent    Age  Gender  Trans  Sexuality  Ethnicity  Dependents  \
# ...

# %%
missing_data.iloc[1:12, 15:30]
# Out:
#     YearsCodePro  CareerSat  JobSat  MgrIdiot  MgrMoney  MgrWant  JobSeek  \
# 1          False      False   False     False     False    False    False
# 2          False      False   False      True      True     True    False
# 3          False      False   False     False     False    False    False
# 4          False      False   False     False     False    False    False
# 5          False      False   False     False     False    False    False
# 6          False      False   False     False     False    False    False
# 7          False      False   False     False     False    False    False
# 8          False      False   False     False     False    False    False
# 9          False      False   False     False     False    False    False
# 10         False      False   False     False     False    False    False
# 11         False      False   False      True      True     True    False
#
#     LastHireDate  LastInt  FizzBuzz  JobFactors  ResumeUpdate  CurrencySymbol  \
# ...

# %% [markdown]
# Count missing values in each column Using a for loop in Python, we can quickly figure out the number of missing values in each column. As mentioned above, "True" represents a missing value, "False" means the value is present in the dataset.
# In the body of the for loop the method ".value_counts()" counts the number of "True" values.

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Respondent
# False    11552
# Name: Respondent, dtype: int64
#
# MainBranch
# False    11552
# Name: MainBranch, dtype: int64
#
# Hobbyist
# False    11552
# Name: Hobbyist, dtype: int64
#
# OpenSourcer
# False    11552
# Name: OpenSourcer, dtype: int64
#
# OpenSource
# False    11471
# True        81
# Name: OpenSource, dtype: int64
#
# Employment
# False    11552
# Name: Employment, dtype: int64
#
# Country
# False    11552
# Name: Country, dtype: int64
#
# Student
# False    11499
# True        53
# Name: Student, dtype: int64
#
# EdLevel
# False    11436
# True       116
# Name: EdLevel, dtype: int64
#
# UndergradMajor
# False    10812
# True       740
# Name: UndergradMajor, dtype: int64
#
# EduOther
# False    11388
# True       164
# Name: EduOther, dtype: int64
#
# OrgSize
# False    11454
# True        98
# Name: OrgSize, dtype: int64
#
# DevType
# False    11485
# True        67
# Name: DevType, dtype: int64
#
# YearsCode
# False    11543
# True         9
# ...

# %%
#or other method

# %%
# Count total NaN at each column in DataFrame
print("Count of NaN by column")
print(df.isnull().sum())
# Out:
# Count of NaN by column
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       547
# Ethnicity       683
# Dependents      144
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %%
# Count total NaN in DataFrame 
print('Count of total NaN in DataFrame',df.isnull().sum().sum())
# Out:
# Count of total NaN in DataFrame 31381

# %%
# Finding Missing Values

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
missing_data['WorkLoc'].value_counts()
# Out:
# False    11520
# True        32
# Name: WorkLoc, dtype: int64

# %%
# or
print(df['WorkLoc'].isnull().sum())
# Out:
# 32

# %%
######- ADDITIONAL QUESTION "Find out how many rows are missing in the column 'EdLevel' before droping duplicate rows"

missing_data_1= df.isnull()
rows_EdLevel=missing_data_1['EdLevel'].value_counts() 

rows_EdLevel
# Out:
# False    11436
# True       116
# Name: EdLevel, dtype: int64

# %%
#or

print(df['EdLevel'].isnull().sum())
# Out:
# 116

# %%
######- ADDITIONAL QUESTION "Find out how many rows are missing in the column 'EdLevel' after droping duplicate rows"

missing_data_after_drop = df1.isnull()
rows_EdLevel_after_drop=missing_data_after_drop['EdLevel'].value_counts() 

rows_EdLevel_after_drop
# Out:
# False    11286
# True       112
# Name: EdLevel, dtype: int64

# %%
#EdLEvel missing value before duplicatedrop

print(df['EdLevel'].isnull().sum())
# Out:
# 116

# %%
#EdLEvel missing value after duplicatedrop
print(df1['EdLevel'].isnull().sum())
# Out:
# 112

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here

# %%
# for original dataframe
df['WorkLoc'].value_counts()
# Out:
# Office                                            6905
# Home                                              3638
# Other place, such as a coworking space or cafe     977
# Name: WorkLoc, dtype: int64

# %%
# for data frame after dropping duplicates (ref - missing_data_after_drop['WorkLoc'].value_counts() )
df1['WorkLoc'].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference
# "Office"
worklock_major_value = df["WorkLoc"].mode()
print(worklock_major_value)
# Out:
# 0    Office
# dtype: object

# %%
worklock_major_value[0]
# Out:
# 'Office'

# %%
#for questionaire ("Employment") - What is the majority category under the column Employment?
df["Employment"].mode()
# Out:
# 0    Employed full-time
# dtype: object

# %%
#Under the column " UndergradMajor", which category has the minimum number of rows?

df["UndergradMajor"].value_counts()
# Out:
# Computer science, computer engineering, or software engineering          7053
# Information systems, information technology, or system administration     806
# Another engineering discipline (ex. civil, electrical, mechanical)        769
# Web development or web design                                             417
# A natural science (ex. biology, chemistry, physics)                       409
# Mathematics or statistics                                                 375
# A business discipline (ex. accounting, finance, marketing)                247
# A social science (ex. anthropology, psychology, political science)        212
# A humanities discipline (ex. literature, history, philosophy)             209
# Fine arts or performing arts (ex. graphic design, music, studio art)      165
# I never declared a major                                                  126
# A health science (ex. nursing, pharmacy, radiology)                        24
# Name: UndergradMajor, dtype: int64

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
# Verify if there is no empty rows in the WorkLoc column

print(df['WorkLoc'].isnull().sum())
# Out:
# 32

# %%
df.WorkLoc.value_counts()
# Out:
# Office                                            6905
# Home                                              3638
# Other place, such as a coworking space or cafe     977
# Name: WorkLoc, dtype: int64

# %%
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority

df_add_office=df["WorkLoc"].fillna("Office")

print(df_add_office.value_counts()) # 32 Office values have replaced NaN values in the WorkLoc column
# Out:
# Office                                            6937
# Home                                              3638
# Other place, such as a coworking space or cafe     977
# Name: WorkLoc, dtype: int64

# %%
#another method - using not string "Office" but variable instead (worklock_major_value[0])

df_workloc_after_nan_replace111 = df['WorkLoc'].fillna(worklock_major_value[0])
df_workloc_after_nan_replace111
# Out:
# 0                                                  Home
# 1                                                Office
# 2                                                  Home
# 3                                                  Home
# 4        Other place, such as a coworking space or cafe
#                               ...
# 11547                                              Home
# 11548                                              Home
# 11549                                            Office
# 11550                                              Home
# 11551                                            Office
# Name: WorkLoc, Length: 11552, dtype: object

# %%
df_workloc_after_nan_replace111.value_counts()
# Out:
# Office                                            6937
# Home                                              3638
# Other place, such as a coworking space or cafe     977
# Name: WorkLoc, dtype: int64

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here

# %%
df_workloc_after_nan_replace111.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df[["CompFreq"]]
# Out:
#       CompFreq
# 0       Yearly
# 1       Yearly
# 2       Yearly
# 3      Monthly
# 4       Yearly
# ...        ...
# 11547   Yearly
# 11548   Yearly
# 11549   Yearly
# 11550   Yearly
# 11551      NaN
#
# [11552 rows x 1 columns]

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %%
df["CompFreq"].value_counts()
# Out:
# Yearly     6163
# Monthly    4846
# Weekly      337
# Name: CompFreq, dtype: int64

# %%
df[["CompTotal"]]
# Out:
#        CompTotal
# 0        61000.0
# 1       138000.0
# 2        90000.0
# 3        29000.0
# 4        90000.0
# ...          ...
# 11547   130000.0
# 11548    74400.0
# 11549   105000.0
# 11550    80000.0
# 11551        NaN
#
# [11552 rows x 1 columns]

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# your code goes here

# %%
df["CompFreq"]
# Out:
# 0         Yearly
# 1         Yearly
# 2         Yearly
# 3        Monthly
# 4         Yearly
#           ...
# 11547     Yearly
# 11548     Yearly
# 11549     Yearly
# 11550     Yearly
# 11551        NaN
# Name: CompFreq, Length: 11552, dtype: object

# %%
df[["CompFreqManipulation"]]=df[["CompFreq"]].copy()

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
df.loc[(df.CompFreqManipulation == 'Yearly'),"CompFreqManipulation"]=1
df["CompFreqManipulation"]
# Out:
# 0              1
# 1              1
# 2              1
# 3        Monthly
# 4              1
#           ...
# 11547          1
# 11548          1
# 11549          1
# 11550          1
# 11551        NaN
# Name: CompFreqManipulation, Length: 11552, dtype: object

# %%
df.loc[(df.CompFreqManipulation == 'Monthly'),"CompFreqManipulation"]=12
df["CompFreqManipulation"]
# Out:
# 0          1
# 1          1
# 2          1
# 3         12
# 4          1
#         ...
# 11547      1
# 11548      1
# 11549      1
# 11550      1
# 11551    NaN
# Name: CompFreqManipulation, Length: 11552, dtype: object

# %%
df.loc[(df.CompFreqManipulation == 'Weekly'),"CompFreqManipulation"]=52
df["CompFreqManipulation"]
# Out:
# 0          1
# 1          1
# 2          1
# 3         12
# 4          1
#         ...
# 11547      1
# 11548      1
# 11549      1
# 11550      1
# 11551    NaN
# Name: CompFreqManipulation, Length: 11552, dtype: object

# %%
df["CompFreqManipulation"].value_counts()
# Out:
# 1     6163
# 12    4846
# 52     337
# Name: CompFreqManipulation, dtype: int64

# %%
df['NormalizedAnnualCompensation'] = df["CompFreqManipulation"] * df["CompTotal"]

# %%
df[['NormalizedAnnualCompensation']]
# Out:
#       NormalizedAnnualCompensation
# 0                            61000
# 1                           138000
# 2                            90000
# 3                           348000
# 4                            90000
# ...                            ...
# 11547                       130000
# 11548                        74400
# 11549                       105000
# 11550                        80000
# 11551                          NaN
#
# [11552 rows x 1 columns]

# %%
df[['NormalizedAnnualCompensation']] .median()
# Out:
# NormalizedAnnualCompensation    100000.0
# dtype: float64

# %%
df['NormalizedAnnualCompensation'] .median()
# Out:
# 100000.0

# %%
df[['NormalizedAnnualCompensation']] .mean()
# Out:
# NormalizedAnnualCompensation    6.076494e+06
# dtype: float64

# %%
df['NormalizedAnnualCompensation'] .mean()
# Out:
# 6076493.933091044

# %%
df['NormalizedAnnualCompensation'] .max()
# Out:
# 8400000000.0

# %%
df['NormalizedAnnualCompensation'] .min()
# Out:
# 0.0

# %%
(df['NormalizedAnnualCompensation'] .max())/(df['NormalizedAnnualCompensation'] .median()) ###### max salary divided by median salary
# Out:
# 84000.0

# %%
#Another method

# %%
df["CompFreq"].unique()
# Out:
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %%
### df["CompFreq"].replace(to_replace="Yearly",value=1,inplace=True)
#df["CompFreq"].replace(to_replace="Monthly",value=12,inplace=True)
#df["CompFreq"].replace(to_replace="Weekly",value=52,inplace=True)
#df["CompFreq"].unique()
#df["CompFreq"].value_counts()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
